# %% [markdown]
# # Data Load

# %%
import os
import pandas as pd
from matplotlib import pyplot as plt
import numpy as np

# %%
base_path= 'C:/Users/baek/Desktop/NURO/data'
file_list= os.listdir(base_path)

# %%
path_fault1_ex = 'C:/Users/baek/Desktop/NURO/data/fault1/external'
path_fault1_in = 'C:/Users/baek/Desktop/NURO/data/fault1/internal'

path_normal_ex = 'C:/Users/baek/Desktop/NURO/data/normal/external'
path_normal_in = 'C:/Users/baek/Desktop/NURO/data/normal/internal'

# %%
dat_f1 = [[] for i in range(0,2)]
dat_f2 = [[] for i in range(0,2)]
dat_n = []

# %%
temp =pd.read_csv(path_fault1_ex + '/'+os.listdir(path_fault1_ex)[0], sep = '\t' )
dat_f1[0].append(temp)
temp =pd.read_csv(path_fault1_ex + '/'+os.listdir(path_fault1_ex)[1], sep = '\t' )
dat_f1[0].append(temp)
temp =pd.read_csv(path_fault1_ex + '/'+os.listdir(path_fault1_ex)[2], sep = '\t' )
dat_f1[0].append(temp)


temp =pd.read_csv(path_fault1_in + '/'+os.listdir(path_fault1_in)[0], sep = ',' , low_memory=False)
dat_f1[1].append(temp)
temp =pd.read_csv(path_fault1_in + '/'+os.listdir(path_fault1_in)[1], sep = ',' , low_memory=False)
dat_f1[1].append(temp)
temp =pd.read_csv(path_fault1_in + '/'+os.listdir(path_fault1_in)[2], sep = ',' , low_memory=False)
dat_f1[1].append(temp)

temp =pd.read_csv(path_normal_ex + '/'+os.listdir(path_normal_ex)[0], sep = '\t' )
dat_n.append(temp)
temp =pd.read_csv(path_normal_ex + '/'+os.listdir(path_normal_ex)[1], sep = '\t' )
dat_n.append(temp)
temp =pd.read_csv(path_normal_ex + '/'+os.listdir(path_normal_ex)[2], sep = '\t' )
dat_n.append(temp)

# %% [markdown]
# # Data Check

# %%
## 내부데이터
dat_f1[1][0]
# Out:
#                          timeline       EventLog  CoreSN  encoderAngle  \
# 0      2022-05-30 12:50:57.599828  Program Start     NaN           NaN
# 1      2022-05-30 12:50:58.250737            NaN  core01   1115.953466
# 2      2022-05-30 12:50:58.253752            NaN  core02   3601.664266
# 3      2022-05-30 12:50:58.333515            NaN  core01   1115.953575
# 4      2022-05-30 12:50:58.336525            NaN  core02   3601.664592
# ...                           ...            ...     ...           ...
# 93798  2022-05-30 13:37:03.621968            NaN  core02   4233.281431
# 93799  2022-05-30 13:37:03.688820            NaN  core01   1754.463628
# 93800  2022-05-30 13:37:03.694776            NaN  core02   4241.303735
# 93801  2022-05-30 13:37:03.737658            NaN  core01   1763.484056
# 93802  2022-05-30 13:37:03.740686            NaN  core02   4246.777102
#
#        encoderVelocity  CommandTorque  ActualTorque  BoardTemp
# ...

# %%
## 진동데이터
dat_f1[0][0]
# Out:
#        address        Time(s)   ax(g)   ay(g)   az(g)  wx(deg/s)  wy(deg/s)  \
# 0         0x50   12:51:31.907 -0.0107  0.0469  0.9966        0.0        0.0
# 1         0x50   12:51:31.907 -0.0107  0.0469  0.9966        0.0        0.0
# 2         0x50   12:51:31.919 -0.0117  0.0464  0.9961        0.0        0.0
# 3         0x50   12:51:31.925 -0.0117  0.0464  0.9961        0.0        0.0
# 4         0x50   12:51:31.935 -0.0103  0.0474  0.9966        0.0        0.0
# ...        ...            ...     ...     ...     ...        ...        ...
# 366089    0x50   13:52:14.183 -0.0122  0.0479  0.9966        0.0        0.0
# 366090    0x50   13:52:14.183 -0.0122  0.0479  0.9966        0.0        0.0
# 366091    0x50   13:52:14.214 -0.0127  0.0483  0.9966        0.0        0.0
# 366092    0x50   13:52:14.214 -0.0127  0.0483  0.9966        0.0        0.0
# 366093    0x50   13:52:14.214 -0.0122  0.0474  0.9956        0.0        0.0
#
# ...

# %% [markdown]
# # Data Visualization

# %%
## 코어1 : 정상, 코어2 : 결함1 
plt.figure(figsize=(30, 15))

plt.plot(dat_f1[1][0].loc[dat_f1[1][0]['CoreSN'] == 'core0'+str(1),'ActualTorque'][0:3000],label='CORE'+str(1))
plt.plot(dat_f1[1][0].loc[dat_f1[1][0]['CoreSN'] == 'core0'+str(2),'ActualTorque'][0:3000],label='CORE'+str(2))
title_font = {
            'fontsize' : 32,
            'fontweight' : 'bold'
        }
plt.title('ActualTorque '+ str(1), fontdict=title_font)
plt.legend(fontsize=20)
plt.show()

# %%
plt.figure(figsize=(30, 15))

plt.plot(dat_f1[1][1].loc[dat_f1[1][1]['CoreSN'] == 'core0'+str(1),'ActualTorque'][0:3000],label='CORE'+str(1))
plt.plot(dat_f1[1][1].loc[dat_f1[1][1]['CoreSN'] == 'core0'+str(2),'ActualTorque'][0:3000],label='CORE'+str(2))
title_font = {
            'fontsize' : 32,
            'fontweight' : 'bold'
        }
plt.title('ActualTorque '+ str(1.5), fontdict=title_font)
plt.legend(fontsize=20)
plt.show()

# %%
plt.figure(figsize=(30, 15))

plt.plot(dat_f1[1][2].loc[dat_f1[1][2]['CoreSN'] == 'core0'+str(1),'ActualTorque'][0:3000],label='CORE'+str(1))
plt.plot(dat_f1[1][2].loc[dat_f1[1][2]['CoreSN'] == 'core0'+str(2),'ActualTorque'][0:3000],label='CORE'+str(2))
title_font = {
            'fontsize' : 32,
            'fontweight' : 'bold'
        }
plt.title('ActualTorque '+ str(2.0), fontdict=title_font)
plt.legend(fontsize=20)
plt.show()

# %%
## 코어1 : 정상, 코어2 : 결함1 
plt.figure(figsize=(30, 15))

plt.plot(dat_f1[1][0].loc[dat_f1[1][0]['CoreSN'] == 'core0'+str(1),'BoardTemp'][0:],label='CORE'+str(1))
plt.plot(dat_f1[1][0].loc[dat_f1[1][0]['CoreSN'] == 'core0'+str(2),'BoardTemp'][0:],label='CORE'+str(2))
title_font = {
            'fontsize' : 32,
            'fontweight' : 'bold'
        }
plt.title('BoardTemp '+ str(1.0), fontdict=title_font)
plt.legend(fontsize=20)
plt.show()

# %%
## 코어1 : 정상, 코어2 : 결함1 
plt.figure(figsize=(30, 15))

plt.plot(dat_f1[1][1].loc[dat_f1[1][1]['CoreSN'] == 'core0'+str(1),'BoardTemp'][0:],label='CORE'+str(1))
plt.plot(dat_f1[1][1].loc[dat_f1[1][1]['CoreSN'] == 'core0'+str(2),'BoardTemp'][0:],label='CORE'+str(2))
title_font = {
            'fontsize' : 32,
            'fontweight' : 'bold'
        }
plt.title('BoardTemp '+ str(1.5), fontdict=title_font)
plt.legend(fontsize=20)
plt.show()

# %%
## 코어1 : 정상, 코어2 : 결함1 
plt.figure(figsize=(30, 15))

plt.plot(dat_f1[1][2].loc[dat_f1[1][2]['CoreSN'] == 'core0'+str(1),'BoardTemp'][0:],label='CORE'+str(1))
plt.plot(dat_f1[1][2].loc[dat_f1[1][2]['CoreSN'] == 'core0'+str(2),'BoardTemp'][0:],label='CORE'+str(2))
title_font = {
            'fontsize' : 32,
            'fontweight' : 'bold'
        }
plt.title('BoardTemp '+ str(2.0), fontdict=title_font)
plt.legend(fontsize=20)
plt.show()

# %%
## 코어1 : 정상, 코어2 : 결함1 
plt.figure(figsize=(30, 15))

plt.plot(dat_f1[1][0].loc[dat_f1[1][0]['CoreSN'] == 'core0'+str(1),'encoderVelocity'][0:3000],label='CORE'+str(1))
plt.plot(dat_f1[1][0].loc[dat_f1[1][0]['CoreSN'] == 'core0'+str(2),'encoderVelocity'][0:3000],label='CORE'+str(2))
title_font = {
            'fontsize' : 32,
            'fontweight' : 'bold'
        }
plt.title('encoderVelocity '+ str(1.0), fontdict=title_font)
plt.legend(fontsize=20)
plt.show()

# %%
## 코어1 : 정상, 코어2 : 결함1 
plt.figure(figsize=(30, 15))

plt.plot(dat_f1[1][1].loc[dat_f1[1][1]['CoreSN'] == 'core0'+str(1),'encoderVelocity'][0:3000],label='CORE'+str(1))
plt.plot(dat_f1[1][1].loc[dat_f1[1][1]['CoreSN'] == 'core0'+str(2),'encoderVelocity'][0:3000],label='CORE'+str(2))
title_font = {
            'fontsize' : 32,
            'fontweight' : 'bold'
        }
plt.title('encoderVelocity '+ str(1.5), fontdict=title_font)
plt.legend(fontsize=20)
plt.show()

# %%
## 코어1 : 정상, 코어2 : 결함1 
plt.figure(figsize=(30, 15))

plt.plot(dat_f1[1][2].loc[dat_f1[1][2]['CoreSN'] == 'core0'+str(1),'encoderVelocity'][0:3000],label='CORE'+str(1))
plt.plot(dat_f1[1][2].loc[dat_f1[1][2]['CoreSN'] == 'core0'+str(2),'encoderVelocity'][0:3000],label='CORE'+str(2))
title_font = {
            'fontsize' : 32,
            'fontweight' : 'bold'
        }
plt.title('encoderVelocity '+ str(2.0), fontdict=title_font)
plt.legend(fontsize=20)
plt.show()

# %%
## 코어1 : 정상, 코어2 : 결함1 
plt.figure(figsize=(30, 15))

plt.plot(dat_f1[1][0].loc[dat_f1[1][0]['CoreSN'] == 'core0'+str(1),'CommandTorque'][0:3000],label='CORE'+str(1))
plt.plot(dat_f1[1][0].loc[dat_f1[1][0]['CoreSN'] == 'core0'+str(2),'CommandTorque'][0:3000],label='CORE'+str(2))
title_font = {
            'fontsize' : 32,
            'fontweight' : 'bold'
        }
plt.title('CommandTorque '+ str(1.0), fontdict=title_font)
plt.legend(fontsize=20)
plt.show()

# %%
## 코어1 : 정상, 코어2 : 결함1 
plt.figure(figsize=(30, 15))

plt.plot(dat_f1[1][1].loc[dat_f1[1][1]['CoreSN'] == 'core0'+str(1),'CommandTorque'][0:3000],label='CORE'+str(1))
plt.plot(dat_f1[1][1].loc[dat_f1[1][1]['CoreSN'] == 'core0'+str(2),'CommandTorque'][0:3000],label='CORE'+str(2))
title_font = {
            'fontsize' : 32,
            'fontweight' : 'bold'
        }
plt.title('CommandTorque '+ str(1.5), fontdict=title_font)
plt.legend(fontsize=20)
plt.show()

# %%
## 코어1 : 정상, 코어2 : 결함1 
plt.figure(figsize=(30, 15))

plt.plot(dat_f1[1][2].loc[dat_f1[1][2]['CoreSN'] == 'core0'+str(1),'CommandTorque'][0:3000],label='CORE'+str(1))
plt.plot(dat_f1[1][2].loc[dat_f1[1][2]['CoreSN'] == 'core0'+str(2),'CommandTorque'][0:3000],label='CORE'+str(2))
title_font = {
            'fontsize' : 32,
            'fontweight' : 'bold'
        }
plt.title('CommandTorque '+ str(2.0), fontdict=title_font)
plt.legend(fontsize=20)
plt.show()

# %%
plt.figure(figsize=(30, 15))

plt.plot(dat_n[0].loc[1000:1100,'ax(g)']- dat_n[0].loc[1000:1100,'ax(g)'].mean(),label='CORE'+str(1))
plt.plot(dat_f1[0][0].loc[1000:1100,'ax(g)'] - dat_f1[0][0].loc[1000:1100,'ax(g)'].mean() ,label='CORE'+str(2))

title_font = {
            'fontsize' : 32,
            'fontweight' : 'bold'
        }
plt.title('ax(g) '+ str(1), fontdict=title_font)
plt.legend(fontsize=20)
plt.show()

# %%
plt.figure(figsize=(30, 15))

plt.plot(dat_n[1].loc[1000:1100,'ax(g)']- dat_n[1].loc[1000:1100,'ax(g)'].mean(),label='CORE'+str(1))
plt.plot(dat_f1[0][1].loc[1000:1100,'ax(g)']- dat_f1[0][1].loc[1000:1100,'ax(g)'].mean(),label='CORE'+str(2))

title_font = {
            'fontsize' : 32,
            'fontweight' : 'bold'
        }
plt.title('ax(g) '+ str(1.5), fontdict=title_font)
plt.legend(fontsize=20)
plt.show()

# %%
plt.figure(figsize=(30, 15))

plt.plot(dat_n[2].loc[1000:1100,'ax(g)']- dat_n[2].loc[1000:1100,'ax(g)'].mean(),label='CORE'+str(1))
plt.plot(dat_f1[0][2].loc[1000:1100,'ax(g)']- dat_f1[0][2].loc[1000:1100,'ax(g)'].mean(),label='CORE'+str(2))

title_font = {
            'fontsize' : 32,
            'fontweight' : 'bold'
        }
plt.title('ax(g) '+ str(2.0), fontdict=title_font)
plt.legend(fontsize=20)
plt.show()

# %%
plt.figure(figsize=(30, 15))

plt.plot(dat_n[0].loc[10000:50000,'ay(g)']- dat_n[0].loc[10000:50000,'ay(g)'].mean(),label='CORE'+str(1))
plt.plot(dat_f1[0][0].loc[10000:50000,'ay(g)'] - dat_f1[0][0].loc[10000:50000,'ay(g)'].mean() ,label='CORE'+str(2))
title_font = {
            'fontsize' : 32,
            'fontweight' : 'bold'
        }
plt.title('ay(g) '+ str(1), fontdict=title_font)
plt.legend(fontsize=20)
plt.show()

# %%
plt.figure(figsize=(30, 15))

plt.plot(dat_n[1].loc[10000:50000,'ay(g)']- dat_n[1].loc[10000:50000,'ay(g)'].mean(),label='CORE'+str(1))
plt.plot(dat_f1[0][1].loc[10000:50000,'ay(g)'] - dat_f1[0][1].loc[10000:50000,'ay(g)'].mean() ,label='CORE'+str(2))

title_font = {
            'fontsize' : 32,
            'fontweight' : 'bold'
        }
plt.title('ay(g) '+ str(1.5), fontdict=title_font)
plt.legend(fontsize=20)
plt.show()

# %%
plt.figure(figsize=(30, 15))

plt.plot(dat_n[2].loc[10000:50000,'ay(g)']+ dat_n[2].loc[10000:50000,'ay(g)'].mean(),label='CORE'+str(1))
plt.plot(dat_f1[0][2].loc[10000:50000,'ay(g)'] - dat_f1[0][2].loc[10000:50000,'ay(g)'].mean() ,label='CORE'+str(2))

title_font = {
            'fontsize' : 32,
            'fontweight' : 'bold'
        }
plt.title('ay(g) '+ str(2.0), fontdict=title_font)
plt.legend(fontsize=20)
plt.show()

# %%
plt.figure(figsize=(30, 15))

plt.plot(dat_n[0].loc[10000:50000,'az(g)']- dat_n[0].loc[10000:50000,'az(g)'].mean(),label='CORE'+str(1))
plt.plot(dat_f1[0][0].loc[10000:50000,'az(g)'] - dat_f1[0][0].loc[10000:50000,'az(g)'].mean() ,label='CORE'+str(2))
title_font = {
            'fontsize' : 32,
            'fontweight' : 'bold'
        }
plt.title('az(g) '+ str(1), fontdict=title_font)
plt.legend(fontsize=20)
plt.show()
